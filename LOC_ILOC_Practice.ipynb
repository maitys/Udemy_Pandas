# %% [markdown]
# # `loc()` and `iloc()` in Pandas

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # Show all results without print
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:78% !important; }</style>"))

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
pd.__version__
# Out:
# <style>.container { width:78% !important; }</style>
# '0.25.1'

# %%
# read the data from the downloaded CSV file.
data = pd.read_csv('https://s3-eu-west-1.amazonaws.com/shanebucket/downloads/uk-500.csv')
# set a numeric id for use as an index for examples.
data['id'] = [random.randint(0,1000) for x in range(data.shape[0])]
 
data.head(5)
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  652
# 1     http://www.capgeminiamerica.co.uk   56
# 2      http://www.elliottjohnwesq.co.uk  110
# 3          http://www.mcmahanbenl.co.uk  244
# 4        http://www.champagneroom.co.uk  688

# %% [markdown]
# ## Selecting pandas data using “iloc”

# %%
# Single selections using iloc and DataFrame
# Rows:
data.iloc[0] # first row of data frame (Aleshia Tomkiewicz) - Note a Series data type output.
data.iloc[[1]] # second row of data frame (Evan Zigomalas)
data.iloc[[-1]] # last row of data frame (Mi Richan)
# Columns:
data.iloc[:,0] # first column of data frame (first_name)
data.iloc[:,1] # second column of data frame (last_name)
data.iloc[:,-1] # last column of data frame (id)
# Out:
# first_name                                   Aleshia
# last_name                                 Tomkiewicz
# company_name                 Alan D Rosenburg Cpa Pc
# address                                 14 Taylor St
# city                               St. Stephens Ward
# county                                          Kent
# postal                                       CT2 7PP
# phone1                                  01835-703597
# phone2                                  01944-369967
# email                        atomkiewicz@hotmail.com
# web             http://www.alandrosenburgcpapc.co.uk
# id                                               652
# Name: 0, dtype: object
#   first_name  last_name        company_name      address        city  \
# 1       Evan  Zigomalas  Cap Gemini America  5 Binney St  Abbey Ward
#
#             county    postal        phone1        phone2  \
# 1  Buckinghamshire  HP11 2AX  01937-864715  01714-737668
#
#                       email                                web  id
# 1  evan.zigomalas@gmail.com  http://www.capgeminiamerica.co.uk  56
#     first_name last_name                    company_name          address  \
# 499         Mi    Richan  Nelson Wright Haworth Golf Crs  6 Norwood Grove
#
#                   city        county   postal        phone1        phone2  \
# 499  Tanworth-in-Arden  Warwickshire  B94 5RZ  01451-785624  01202-738406
#
#               email                                          web   id
# 499  mi@hotmail.com  http://www.nelsonwrighthaworthgolfcrs.co.uk  444
# 0        Aleshia
# 1           Evan
# 2         France
# 3        Ulysses
# 4         Tyisha
#          ...
# 495        Avery
# 496         Reid
# 497    Charlette
# 498    Celestina
# 499           Mi
# Name: first_name, Length: 500, dtype: object
# 0      Tomkiewicz
# 1       Zigomalas
# 2         Andrade
# 3       Mcwalters
# 4          Veness
#           ...
# 495          Veit
# 496       Euresti
# 497      Brenning
# 498         Keeny
# 499        Richan
# Name: last_name, Length: 500, dtype: object
# 0      652
# 1       56
# 2      110
# 3      244
# 4      688
#       ...
# 495    353
# 496    993
# 497    549
# 498    662
# 499    444
# Name: id, Length: 500, dtype: int64

# %%
# Multiple row and column selections using iloc and DataFrame
data.iloc[0:5] # first five rows of dataframe
data.iloc[:, 0:2] # first two columns of data frame with all rows
data.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
data.iloc[0:5, 5:8] # first 5 rows and 5th, 6th, 7th columns of data frame (county -> phone1).
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  652
# 1     http://www.capgeminiamerica.co.uk   56
# 2      http://www.elliottjohnwesq.co.uk  110
# 3          http://www.mcmahanbenl.co.uk  244
# 4        http://www.champagneroom.co.uk  688
#     first_name   last_name
# 0      Aleshia  Tomkiewicz
# 1         Evan   Zigomalas
# 2       France     Andrade
# 3      Ulysses   Mcwalters
# 4       Tyisha      Veness
# ..         ...         ...
# 495      Avery        Veit
# 496       Reid     Euresti
# 497  Charlette    Brenning
# 498  Celestina       Keeny
# 499         Mi      Richan
#
# [500 rows x 2 columns]
#    first_name        county    postal
# 0     Aleshia          Kent   CT2 7PP
# 3     Ulysses  Lincolnshire  DN36 5RP
# 6        Marg   Southampton  SO14 3TY
# 24       Tess   West Sussex  PO19 1RH
#             county    postal        phone1
# 0             Kent   CT2 7PP  01835-703597
# 1  Buckinghamshire  HP11 2AX  01937-864715
# 2      Bournemouth   BH6 3BE  01347-368222
# 3     Lincolnshire  DN36 5RP  01912-771311
# 4    West Midlands   B70 9DT  01547-429341

# %% [markdown]
# ## Selecting pandas data using “loc”

# %%
data.set_index("last_name", inplace=True)
data.head()
# Out:
#            first_name             company_name            address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc       14 Taylor St
# Zigomalas        Evan       Cap Gemini America        5 Binney St
# Andrade        France      Elliott, John W Esq       8 Moor Place
# Mcwalters     Ulysses           Mcmahan, Ben L      505 Exeter Rd
# Veness         Tyisha           Champagne Room  5396 Forth Street
#
#                                       city           county    postal  \
# last_name
# Tomkiewicz               St. Stephens Ward             Kent   CT2 7PP
# Zigomalas                       Abbey Ward  Buckinghamshire  HP11 2AX
# Andrade     East Southbourne and Tuckton W      Bournemouth   BH6 3BE
# Mcwalters               Hawerby cum Beesby     Lincolnshire  DN36 5RP
# Veness          Greets Green and Lyng Ward    West Midlands   B70 9DT
#
#                   phone1        phone2                       email  \
# last_name
# Tomkiewicz  01835-703597  01944-369967     atomkiewicz@hotmail.com
# Zigomalas   01937-864715  01714-737668    evan.zigomalas@gmail.com
# Andrade     01347-368222  01935-821636  france.andrade@hotmail.com
# Mcwalters   01912-771311  01302-601380         ulysses@hotmail.com
# Veness      01547-429341  01290-367248   tyisha.veness@hotmail.com
#
#                                              web   id
# last_name
# Tomkiewicz  http://www.alandrosenburgcpapc.co.uk  652
# Zigomalas      http://www.capgeminiamerica.co.uk   56
# Andrade         http://www.elliottjohnwesq.co.uk  110
# Mcwalters           http://www.mcmahanbenl.co.uk  244
# Veness            http://www.champagneroom.co.uk  688

# %%
data.loc[["Tomkiewicz"]]
# Out:
#            first_name             company_name       address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc  14 Taylor St
#
#                          city county   postal        phone1        phone2  \
# last_name
# Tomkiewicz  St. Stephens Ward   Kent  CT2 7PP  01835-703597  01944-369967
#
#                               email                                   web   id
# last_name
# Tomkiewicz  atomkiewicz@hotmail.com  http://www.alandrosenburgcpapc.co.uk  652

# %%
data.loc[["Tomkiewicz", "Andrade"]]
# Out:
#            first_name             company_name       address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc  14 Taylor St
# Andrade        France      Elliott, John W Esq  8 Moor Place
#
#                                       city       county   postal  \
# last_name
# Tomkiewicz               St. Stephens Ward         Kent  CT2 7PP
# Andrade     East Southbourne and Tuckton W  Bournemouth  BH6 3BE
#
#                   phone1        phone2                       email  \
# last_name
# Tomkiewicz  01835-703597  01944-369967     atomkiewicz@hotmail.com
# Andrade     01347-368222  01935-821636  france.andrade@hotmail.com
#
#                                              web   id
# last_name
# Tomkiewicz  http://www.alandrosenburgcpapc.co.uk  652
# Andrade         http://www.elliottjohnwesq.co.uk  110

# %%
data.loc[["Tomkiewicz", "Andrade"], ["address", "phone1"]]
# Out:
#                  address        phone1
# last_name
# Tomkiewicz  14 Taylor St  01835-703597
# Andrade     8 Moor Place  01347-368222

# %%
data.loc[data["first_name"]=="Aleshia"]
# Out:
#            first_name             company_name       address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc  14 Taylor St
#
#                          city county   postal        phone1        phone2  \
# last_name
# Tomkiewicz  St. Stephens Ward   Kent  CT2 7PP  01835-703597  01944-369967
#
#                               email                                   web   id
# last_name
# Tomkiewicz  atomkiewicz@hotmail.com  http://www.alandrosenburgcpapc.co.uk  652

# %%
data[data["first_name"]=="Aleshia"]
# Out:
#            first_name             company_name       address  \
# last_name
# Tomkiewicz    Aleshia  Alan D Rosenburg Cpa Pc  14 Taylor St
#
#                          city county   postal        phone1        phone2  \
# last_name
# Tomkiewicz  St. Stephens Ward   Kent  CT2 7PP  01835-703597  01944-369967
#
#                               email                                   web   id
# last_name
# Tomkiewicz  atomkiewicz@hotmail.com  http://www.alandrosenburgcpapc.co.uk  652

# %%
data.loc[data["first_name"]=="Aleshia", ["county", "postal"]]
# Out:
#            county   postal
# last_name
# Tomkiewicz   Kent  CT2 7PP

# %%
data[data["first_name"]=="Aleshia"][["county", "postal"]]
# Out:
#            county   postal
# last_name
# Tomkiewicz   Kent  CT2 7PP

# %% [markdown]
# ## Setting values in DataFrames using .loc

# %%
# Change the first name of all rows with an ID greater than 2000 to "John"
data.loc[data['id'] > 2000, "first_name"] = "John"

# Change the first name of all rows with an ID greater than 2000 to "John"
data.loc[data['id'] > 2000, "first_name"] = "John"

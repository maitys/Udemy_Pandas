# %% [markdown]
# ## Visualization

# %% [markdown]
# ## Table of Contents
#
# <ul>
#     <li><a href="#1">1. Intro to Visualization Module</a></li>
#     <li><a href="#1">2. The .plot() Method</a></li>
#     <li><a href="#1">3. Modifying Aesthetics with Templates</a></li>
#     <li><a href="#1">4. Bar Graphs</a></li>
#     <li><a href="#1">5. Pie Charts</a></li>
#     <li><a href="#1">6. Histograms</a></li>
# </ul>

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1.5px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1.5px  black solid !important;
#   color: black !important;
# }

# %%
#To show multiple outputs and misc. changes
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # Show all results without print
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:78% !important; }</style>"))
import warnings
warnings.filterwarnings("ignore")

#Load Packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from pandas_datareader import data
from pandas.tseries import *
pd.__version__
# Out:
# C:\Users\maity\AppData\Local\Temp\ipykernel_15764\1139855241.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:78% !important; }</style>
# '1.5.2'

# %% [markdown]
# <a id='1'></a>
# ### 1. Intro to Visualization Module

# %%
import yfinance as yf
yf.pdr_override()
scor = data.get_data_yahoo(["SCOR"], start=dt.date(2016,9,19), end=dt.datetime.now())
scor.head(n=3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2016-09-19  32.520000  32.560001  31.400000  31.709999  31.709999  671300
# 2016-09-20  31.790001  32.169998  31.440001  31.520000  31.520000  481000
# 2016-09-21  31.590000  31.950001  31.139999  31.600000  31.600000  258000

# %% [markdown]
# <a id='2'></a>
# ### 2. The .plot() Method

# %%
import yfinance as yf
yf.pdr_override()
scor = data.get_data_yahoo(["SCOR"], start=dt.date(2016,9,19), end=dt.datetime.now())
scor.head(n=3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2016-09-19  32.520000  32.560001  31.400000  31.709999  31.709999  671300
# 2016-09-20  31.790001  32.169998  31.440001  31.520000  31.520000  481000
# 2016-09-21  31.590000  31.950001  31.139999  31.600000  31.600000  258000

# %%
scor.plot();

# %%
scor["Open"].plot();

# %%
scor["Open"].plot(color="black");

# %%
scor.plot(y="Volume");
scor.plot(y="High");
scor.plot(y="High", kind='area');
scor.plot(y=["High", "Low"], kind='area', figsize=(10,4), title="Trend");

# %% [markdown]
# <a id='3'></a>
# ### 3. Modifying Aesthetics with Templates

# %%
import yfinance as yf
yf.pdr_override()
scor = data.get_data_yahoo(["SCOR"], start=dt.date(2016,9,19), end=dt.datetime.now())
scor.head(n=3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2016-09-19  32.520000  32.560001  31.400000  31.709999  31.709999  671300
# 2016-09-20  31.790001  32.169998  31.440001  31.520000  31.520000  481000
# 2016-09-21  31.590000  31.950001  31.139999  31.600000  31.600000  258000

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-whitegrid")
scor.plot(y="Close", color="red");

# %%
plt.style.use("fivethirtyeight")
scor.plot(y="Close", color="red", figsize=(10,4));

# %%
plt.style.use("dark_background")
scor.plot(y="Close", color="red", figsize=(10,4));

# %%
plt.style.use("ggplot")
scor.plot(y="Close", color="red", figsize=(10,4));

# %% [markdown]
# <a id='4'></a>
# ### 4. Bar Graphs

# %%
import yfinance as yf
yf.pdr_override()
scor = data.get_data_yahoo(["SCOR"], start=dt.date(2016,9,19), end=dt.datetime.now())
scor.head(n=3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2016-09-19  32.520000  32.560001  31.400000  31.709999  31.709999  671300
# 2016-09-20  31.790001  32.169998  31.440001  31.520000  31.520000  481000
# 2016-09-21  31.590000  31.950001  31.139999  31.600000  31.600000  258000

# %%
def rank_performance(stock_price):
    if stock_price <= 20:
        return "Poor"
    elif stock_price > 20 and stock_price <= 30:
        return "Satisfactory"
    else:
        return "Stellar"

# %%
scor["Close"].apply(rank_performance).value_counts()
# Out:
# Poor            1070
# Satisfactory     443
# Stellar           65
# Name: Close, dtype: int64

# %%
plt.style.use("ggplot")
holder = scor["Close"].apply(rank_performance).value_counts()
holder.plot(kind="bar", color="red", edgecolor="black");

# %%
plt.style.use("ggplot")
holder = scor["Close"].apply(rank_performance).value_counts()
holder.plot(kind="barh", color="silver", edgecolor="black");

# %% [markdown]
# <a id='5'></a>
# ### 5. Pie Charts

# %%
import yfinance as yf
yf.pdr_override()
aapl = data.get_data_yahoo(["AAPL"], start=dt.date(2009,9,19), end=dt.datetime.now())
aapl.head(n=3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2009-09-21  6.581786  6.612857  6.486429  6.572143   5.602214  437715600
# 2009-09-22  6.613929  6.620714  6.530357  6.588571   5.616217  356753600
# 2009-09-23  6.621429  6.746429  6.608214  6.625000   5.647268  593563600

# %%
aapl["Close"].mean()
# Out:
# 50.248313642326465

# %%
def rank_performance(stock_price):
    if stock_price >= 108.57923588026925:
        return "Above Average"
    else:
        return "Below Average"

# %%
plt.style.use("dark_background")
holder = aapl["Close"].apply(rank_performance).value_counts()
holder.plot(kind="pie", legend=True, figsize=(5,4));

# %% [markdown]
# <a id='6'></a>
# ### 6. Histograms

# %%
import yfinance as yf
yf.pdr_override()
goog = data.get_data_yahoo(["GOOG"], start=dt.date(2004,8,19), end=dt.datetime.now())
goog.head(n=3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2004-08-19  2.490664  2.591785  2.390042  2.499133   2.499133  897427216
# 2004-08-20  2.515820  2.716817  2.503118  2.697639   2.697639  458857488
# 2004-08-23  2.758411  2.826406  2.716070  2.724787   2.724787  366857939

# %%
def custom_round(stock_price):
    return int(stock_price/100.0) * 100

# %%
goog["High"].apply(custom_round).value_counts().sort_index()
# Out:
# 0      4183
# 100     437
# Name: High, dtype: int64

# %%
plt.style.use("ggplot")
holder = goog["High"].apply(custom_round).value_counts().sort_index()
holder.plot(kind="hist", bins= 15, edgecolor='black')
# Out:
# <AxesSubplot: ylabel='Frequency'>
